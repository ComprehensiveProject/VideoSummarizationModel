# %%
import os
import imageio_ffmpeg
os.environ["IMAGEIO_FFMPEG_EXE"] = "C:\\ffmpeg\\bin\\ffmpeg.exe"

# %%
import torch
from transformers import pipeline
from pydub import AudioSegment
import speech_recognition as sr
from konlpy.tag import Okt
from gensim import corpora, models
import re
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
import tempfile
from google.cloud import storage, speech_v1p1beta1 as speech
import moviepy.editor as mp
from moviepy.editor import VideoFileClip, ImageSequenceClip
import kss
import dlib
import cv2
import numpy as np
from tqdm import tqdm

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "interview-400010-9abf1ded3113.json"

# Step 0: 영상에서 음성 추출
def extract_audio_from_video(video_file, audio_file):
    video = VideoFileClip(video_file)
    video.audio.write_audiofile(audio_file)
    print(f"Audio extracted to {audio_file}")

# Step 1: 음성 파일에서 텍스트 추출
def audio_to_text(audio_file):
    recognizer = sr.Recognizer()
    audio = AudioSegment.from_file(audio_file)
    audio = audio.set_channels(1)  # 모노로 변환
    audio.export("temp.wav", format="wav")

    with sr.AudioFile("temp.wav") as source:
        audio_data = recognizer.record(source)

    client = speech.SpeechClient()

    # 오디오 파일의 샘플링 속도 확인
    audio = AudioSegment.from_wav("temp.wav")
    sample_rate = audio.frame_rate

    # 오디오 파일을 청크로 나누기
    chunk_length_ms = 10000  # 10초 단위로 청크 나누기
    chunks = [audio[i:i + chunk_length_ms] for i in range(0, len(audio), chunk_length_ms)]

    transcript = ""

    for i, chunk in enumerate(chunks):
        chunk.export(f"chunk{i}.wav", format="wav")
        with open(f"chunk{i}.wav", "rb") as audio_file:
            content = audio_file.read()
        audio = speech.RecognitionAudio(content=content)
        config = speech.RecognitionConfig(
            encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
            sample_rate_hertz=sample_rate,
            language_code="ko-KR",
        )

        try:
            response = client.recognize(config=config, audio=audio)
            transcript += "".join([result.alternatives[0].transcript for result in response.results])
        except Exception as e:
            print(f"Google Cloud Speech-to-Text API request error: {e}")
            raise ValueError(f"Could not request results from Google Cloud Speech-to-Text service; {e}")
        finally:
            os.remove(f"chunk{i}.wav")

    os.remove("temp.wav")
    print("Transcript extracted")
    return transcript

# Step 2: 텍스트 전처리 및 문장 분리
def preprocess_text(text):
    # 한글과 공백만 남기기
    processed_text = re.sub(r'[^가-힣\s]', '', text)
    # KSS를 사용하여 문장 단위로 분리
    sentences = kss.split_sentences(processed_text)
    sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
    print(f"Number of sentences: {len(sentences)}")
    return sentences

# Step 3: 주제 추출 및 요약
def extract_topics_and_summarize(sentences, num_topics=5):
    if not sentences or len(sentences) < 2:
        return {"error": "Not enough data to extract topics. Please provide more text."}

    # 문장 임베딩 모델 로드
    model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
    sentence_embeddings = model.encode(sentences)

    # Ensure num_topics is not greater than the number of unique sentences
    num_topics = min(num_topics, len(sentences))

    if num_topics < 2:
        return {"error": "Not enough data to extract topics."}

    # AgglomerativeClustering 클러스터링 수행
    clustering_model = AgglomerativeClustering(n_clusters=num_topics)
    clustering_model.fit(sentence_embeddings)
    cluster_assignment = clustering_model.labels_

    # 클러스터별 문장 그룹화
    clustered_sentences = {i: [] for i in range(num_topics)}
    for sentence_id, cluster_id in enumerate(cluster_assignment):
        clustered_sentences[cluster_id].append(sentences[sentence_id])

    # 클러스터별로 요약 수행
    summarizer = pipeline("summarization", model="gogamza/kobart-base-v2", tokenizer="gogamza/kobart-base-v2")
    topic_sentences = {}
    for i, sentences in clustered_sentences.items():
        combined_text = ' '.join(sentences)
        if len(combined_text.split()) > 50:  # 50 단어 이상인 경우에만 요약 수행
            summary = summarizer(combined_text, max_length=50, min_length=25, do_sample=False)[0]['summary_text']
        else:
            summary = combined_text
        topic_sentences[f'주제 {i+1}'] = summary

    print("Topics extracted and summarized")
    return topic_sentences

# 주제 관련 문장 찾기
def find_relevant_sentences(sentences, topic_summary, max_duration=60):
    okt = Okt()
    topic_nouns = okt.nouns(topic_summary)
    relevant_sentences = [sentence for sentence in sentences if any(noun in sentence for noun in topic_nouns)]

    total_duration = 0
    relevant_text = []

    for sentence in relevant_sentences:
        duration = len(sentence.split()) / 2.5  # 대략적으로 초당 2.5 단어로 가정
        if total_duration + duration > max_duration:
            break
        relevant_text.append(sentence)
        total_duration += duration

    return relevant_text, total_duration

# 중요 프레임 추출 (1분 내의 영상만을 대상으로)
def extract_important_frames(video_file, start_time, end_time, sample_every_sec=2):
    detector = dlib.get_frontal_face_detector()
    cap = cv2.VideoCapture(video_file)

    frames = []
    timestamps = []
    face_centers = []

    frame_count = 0
    total_frames = int((end_time - start_time) * cap.get(cv2.CAP_PROP_FPS))
    cap.set(cv2.CAP_PROP_POS_MSEC, start_time * 1000)  # 영상의 시작 시간 설정

    with tqdm(total=total_frames // sample_every_sec) as pbar:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            timestamp = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000.0
            if timestamp > end_time:
                break
            if int(timestamp - start_time) % sample_every_sec == 0:
                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                faces = detector(gray)
                if faces:
                    face = faces[0]
                    center_x = (face.left() + face.right()) // 2
                    face_centers.append(center_x)
                else:
                    face_centers.append(frame.shape[1] // 2)  # 얼굴을 찾지 못한 경우 중앙을 중심으로 설정
                frames.append(frame)
                timestamps.append(timestamp)
                # 메모리 해제
                del frame
                frame_count += 1
                pbar.update(1)
                if frame_count % 100 == 0:  # 메모리 해제 빈도를 조정
                    cv2.waitKey(1)
    cap.release()

    print(f"Extracted face centers: {face_centers}")  # Debugging line
    return timestamps, face_centers

# 영상 세로로 자르기
def cut_video_with_focus(video_file, start_time, end_time, output_file, focus_frames):
    video = VideoFileClip(video_file).subclip(start_time, end_time)

    # 영상 크기 조정 (세로 비율 9:16)
    target_height = 720  # 해상도 줄이기
    video = video.resize(height=target_height)

    def crop_center(image, center_x):
        print(f"Received center_x: {center_x}")  # Debugging line
        height, width, _ = image.shape
        new_width = int(height * 9 / 16)
        left = max(0, min(center_x - new_width // 2, width - new_width))
        print(f"Cropping image: height={height}, width={width}, center_x={center_x}, new_width={new_width}, left={left}")  # Debugging line
        cropped_image = image[:, left:left + new_width]
        return cropped_image

    # 임시 디렉토리 생성
    with tempfile.TemporaryDirectory() as temp_dir:
        frame_files = []

        for t, frame in enumerate(video.iter_frames()):
            idx = int((t / len(focus_frames)) * len(focus_frames))
            idx = min(idx, len(focus_frames) - 1)
            center_x = focus_frames[idx]
            print(f"Time: {t}, Index: {idx}, Center X: {center_x}")  # Debugging line
            cropped_frame = crop_center(frame, center_x)

            # 임시 파일에 프레임 저장
            frame_file = os.path.join(temp_dir, f"frame_{t:04d}.png")
            try:
                cv2.imwrite(frame_file, cv2.cvtColor(cropped_frame, cv2.COLOR_RGB2BGR))
                if os.path.exists(frame_file):
                    frame_files.append(frame_file)
                else:
                    print(f"Failed to save frame {t} to {frame_file}")
            except Exception as e:
                print(f"Error saving frame {t}: {e}")

        # 프레임 파일 리스트 확인
        if not frame_files:
            print("No frames were processed.")
            return

        # ImageSequenceClip을 사용하여 프레임 파일로부터 동영상 생성
        try:
            new_clip = ImageSequenceClip(frame_files, fps=video.fps)

            # 원본 비디오에서 오디오 트랙 추출
            audio = video.audio
            new_clip = new_clip.set_audio(audio)

            new_clip.write_videofile(output_file, codec='libx264', audio_codec='aac')
        except Exception as e:
            print(f"Error creating video from frames: {e}")

# %%
video_file = 'videos/news1.mp4'  # 비디오 파일 경로 설정
audio_file = 'videos/extracted_audio.wav'

# Step 0: 영상에서 음성 추출
extract_audio_from_video(video_file, audio_file)
print("Step 0: 음성 추출 완료")

try:
    transcript = audio_to_text(audio_file)
    print("추출된 텍스트:", transcript)
except Exception as e:
    print(f"Error: {e}")
# Out:
# MoviePy - Writing audio in videos/extracted_audio.wav
# MoviePy - Done.
# Audio extracted to videos/extracted_audio.wav
# Step 0: 음성 추출 완료
# Transcript extracted
# 추출된 텍스트: 여러분 안녕하십니까 오늘은 저희가 단독 취재한 내용으로 뉴스 시작하겠습니다 다음 주 월요일부터는 병원에 갈 때신분증을 꼭 챙겨야 합니다 환자가 건강보험 자격이 있는지 혹시 다른 사람 명의로 진료받는 건 아닌지 병원이 확인하기 위해서입니다신분증 대신 휴대전화에 모바일 건강보험증을 설치해서 그걸 병원에 보여 줘도 됩니다 그런데이 모바일다른 사람의 휴대전화 해도 쉽게 설치할 수 있고 또 그걸 병원이 적발하기 어렵다는 사실이 저희 취재 결과 확인됐습니다기자의 단독 보도입니다 신분증 지참 필수 란 안내 포스터가 붙은 한내과의원 의원 협조를 미리 받아모바일 건강보험증으로 진료 접수를 해 봤습니다 건강보험증 qr 코드를 병원 기기로 인식하자 건강 보험 자격 확인이 되고 문제 없이완료됐습니다 하지만 기자가 제시한 모바일 건강보험증은 본인이 아닌 동료의 것입니다 타인 명의의 건강보험증을 병원에 제출했는데걸러내지 못한 겁니다 어떻게 이게 가능한걸까 모바일 건강보험증 앱은 휴대 전화 번호를 입력한뒤 인증번호를 받아 본인임을 확인하는설치할 수 있습니다 그런데 두 사람이 미리 짜고 상대방 휴대전화에 인증번호를 받을 사람의 전화 번호를 입력하고그렇게 받은 인증번호를 전달해 휴대 전화에 입력하면 다른 사람의 모바일 건강보험증이 문제 없이 설치됩니다입을 맞춘다면 다른 사람의 모바일 건강보험증으로 진료를 받을 수 있는 겁니다 이뿐만이아닙니다 한 명에 모바일 건강보험증을 둠각자의 휴대전화에 설치하는 것도 가능했습니다 한 사람의 모발 건강보험증으로 여러 명이 진료 받는 것도 가능할 수 있다는 얘깁니다보험 중엔 사진이 없다 보니 병의원에서 본인 여부를 확인할 방법도 마땅치 않습니다 의료 보험이 없다옆에 사람 QR 신분증만 빌리면 된다 공기계 나 그걸 깔아 와서 그거만 내밀면 사실 저희는 죽을 수밖에 없는 시스템이거든요이런 문제에 대한 대책을 문의하자 건강보험공단은 통신사 인증을 본인 휴대폰으로만 인증 가능하도록 시스템 복원을 검토중이라고 해명했습니다대명시장 백화점 기자 나와 있습니다 이게 다음 주부터 시행되지 문제점이 굉장히 많습니다 이런 것들을 정도는 전혀 사전에못 하고 있던 건가요 보건복지부는 오늘 오전에도이 제도가 월요일부터 시행된다는 내용을 담아서 보도자료를 배포했는데 당연히 이런 내용은 없었습니다저희 취재진에 문제를 제기한 이까 7시간 뒤쯤에 건강보험공단에서 답을들을 수 있었는데요 공단은 다른 사람의 휴대전화로모바일 건강보험증을 발급 받을 수 없게 인증시스템을 보완하는 걸 검토하겠다 이렇게 밝혔습니다 하지만 한 명에 모바일 건강보험여러대의 기기에서 쓸 수는 없다고 설명했는데요 앞서 보셨던 것처럼 명의가 다른 휴대전화에 본인확인을 받는게 가능하다는걸 쉽확인할 수 있었습니다 종합적으로 문제가 뭔지 파악을 해서 대책마련을 하는게 필요해 보입니다 먹으면은 다른 사람이진료 받는게 가능한 거잖아요 입원해서 어떻게 대책이 있는 겁니까 일단 건강보험공단은 두 사람이 작정을 하고 휴대전화 인증번호를 공유하는 것과원칙적으로 방지 하기는 좀 어렵다 기본적으로 건강보험증 관리는 소지자가 한다 이런 입장을 보이고 있습니다 원칙적으로는 맞는 말해도 아니라는 대응이라는 지적을 피할 수는 없습니다 저희가 확인해보니까 지난 5년 동안의 다른 사람의 건강보험증을 이용한연평균 3만 5천 원 정도 적발이 된다고 합니다 이런 허술한 본인 강화 제도로 이런 사례를 얼마나 줄일 수 있을지도 의문입니다알겠습니다 세까지 박 과장이 되었습니다 상 소식입니다 서울에서 아파트 전세 구하기가 갈수록 어려워지면서 전셋값이계속 오르고 있습니다 몇 몇 단지 예선 몇 달 사이에 수억원이 뛰기도 했습니다 더위와 함께 앞으로 전당까지 이호건 기자가서울 성동구에 천세 대규모 아파트 단지입니다 지난달 전용 128 제곱미터 전세15억 5천만 원의 책을 됐습니다 두달전 거래 건보다 오른 겁니다이번 주 서울 아파트 전세가는 12,000 세대 단지 입주를 앞둔 강동구를 제외하고 모든 자치구에서 상승했습니다지난 1년 연속 고른 건데 관련 통계 집회 후네 번째로 긴 상승입니다 가장 큰 원인은 매물부족 이달 서울아파트3만 원 이하로 6개월 정도 와 비교하면 17% 줄어듭니다 올해 서울 입주 예정 물량은 16100으로 지난해보다줄어든데다 전세 빌라 대신 아파트 전세 찾는 손님도 영향을 미쳤습니다 향후 상황도 나아지기 어렵습니다오는 7월 말은 세입자가 최대 5% 만 인상된 전세가로 2년 더 살 수 있게 한 임대차 입법이 4년차가 되는 그러니까 첫 만개를집주인들은 그동안 못 올린 걸 현재 시세에 맞게 한꺼번에 올리는 움직임을 보이고 있습니다 그동안에는 이제 올리고 싶어도못했으니까요 그래서 이번에 인제 그게 끝나니까 이렇게 제대로 올리려고 하는 겁니다 실제로 서초구 아파트 전용 84제곱미터최근 전세가 15억원에 체결했는데이는 1년 전보다 3억 오른 가격입니다 50% 상한선이 없어지는이후에는 가을 이사철과 맞물려 전셋값이 더 오를 가능성이 높습니다 정부도 심각성을 인지하고 다음 주 전세는수도권 공급부족 단기간에 해소할 뾰족한 수가 없어 고민이 커지고 있습니다 SDS 이용합니다이상기후의 여파로 농산물 가격이 좀처럼 잡히지 않고 있습니다 올해는 특히 마늘이 걱정입니다 잦은 비 와부족한 일조량 때문에 상품성이 떨어지는 마늘이 많다고 합니다 현장을 박애린 기자가 취재했습니다수확한 마늘을 말리는 작업이 한창인 제주의 마늘 밭입니다 겉으론 멀쩡해보이지만 데를 벗기니 줄기가 여러 개 나옵니다 마늘한쪽여러 쪽으로 갈라집니다 여기서 쪽이 또네 개 낱개로 분리되지 아니면 이쪽이 너무 작아 상품 가치가 없는 것들입니다마늘 생육기 2 3월 잦은 비바 일조량 부족으로 비교적 따뜻했던 기온이 가장 큰 원인입니다작년 대비 강우량도 많이 왔다고 하더라고요 2 3월 달에 원래 같이 뭐 전체적으로 그 벌 마늘이 생성된 거는마늘 농사 접을까 도저히 하고 있습니다이 밤만 하더라도 상품성 없는 벌마늘 비율이 절반을 넘는데 다른 밥도 상황은수학 해도 팔지 못하는 마늘만 잔뜩 나와 인력은 인력 대로 들고 손해가 막심합니다제주에서 시작된 벌마늘 피해가 전남 경남 등으로 빠르게 확산하면서 정부는 농업 죄로 인정하고 재난지원금 지급에 나섰습니다올해 국산마늘 생산량은 평년보다 줄어들 수밖에 없는 상황 현재는 지난해 저장해둔 마늘이 계속 풀리는 시기라 가격은 유지되고 있는데다음 달이면 저장 물량은 차차 소진됩니다 수입물량 추위를 봐야겠지만 여름 정도부터 마늘 가격이 오를 수 있습니다놓고 보면은 단위당 수확량이 조금 더 떨어질 거예요 가격은 뭐 전이라 평균보다는 상승할 가능성이 있습니다이상기후가 과일이에요 채소 작 황해도 두루 영향을 미치면서 물관리가 1층 까다로워지고 있습니다 SBS 박예린입니다이종섭 전 국방부장관 일 해병대 박정훈 전수 사단장 한 명 재판에 증인으로 채택합니다대통령 시로부터 특정인을 혐의자에서 빼라는 말을 전달 받은 적이 없다며 법정에 나가서 증언 하겠다고 밝혔습니다켜졌습니다 4차혁명 공판의 군사법원에 출석한 박정순 대령 박대령 직원 재판이 없어특검법 수영을 촉구했습니다 대통령은 특검법을 수용하고 국방 장관은 지금처럼 정하게 군사재판에 중립을 지키고오늘 공판에서 재판부는 이중섭 전 국방부장관을 증인으로 불러 달라는 박대령 측 요청을 받았습니다이 전 장관은보류 명령을 하게 된 이유와 관련 있어 명령이 정당한지 확인할 필요가 있다며 증인채택 이유를 설명했습니다이 전 장관의 휴대전화 통화내역과 문자 메시지에 대한 통신자료조회 신청도 허락했습니다 이전 상권 직원 지정된

# %%
# Step 2: 텍스트 전처리
try:
    processed_text = preprocess_text(transcript)
    print("Step 2: 전처리된 텍스트:", processed_text)
except Exception as e:
    print(f"Error: {e}")
# Out:
# [Kss]: Oh! You have mecab in your environment. Kss will take this as a backend! :D
# Number of sentences: 82
# Step 2: 전처리된 텍스트: ['여러분 안녕하십니까', '오늘은 저희가 단독 취재한 내용으로 뉴스 시작하겠습니다', '다음 주 월요일부터는 병원에 갈 때신분증을 꼭 챙겨야 합니다', '환자가 건강보험 자격이 있는지 혹시 다른 사람 명의로 진료받는 건 아닌지 병원이 확인하기 위해서입니다', '신분증 대신 휴대전화에 모바일 건강보험증을 설치해서 그걸 병원에 보여 줘도 됩니다', '그런데이 모바일다른 사람의 휴대전화 해도 쉽게 설치할 수 있고 또 그걸 병원이 적발하기 어렵다는 사실이 저희 취재 결과 확인됐습니다', '기자의 단독 보도입니다', '신분증 지참 필수 란 안내 포스터가 붙은 한내과의원 의원 협조를 미리 받아모바일 건강보험증으로 진료 접수를 해 봤습니다', '건강보험증  코드를 병원 기기로 인식하자 건강 보험 자격 확인이 되고 문제 없이완료됐습니다', '하지만 기자가 제시한 모바일 건강보험증은 본인이 아닌 동료의 것입니다', '타인 명의의 건강보험증을 병원에 제출했는데걸러내지 못한 겁니다', '어떻게 이게 가능한걸까 모바일 건강보험증 앱은 휴대 전화 번호를 입력한뒤 인증번호를 받아 본인임을 확인하는설치할 수 있습니다', '그런데 두 사람이 미리 짜고 상대방 휴대전화에 인증번호를 받을 사람의 전화 번호를 입력하고그렇게 받은 인증번호를 전달해 휴대 전화에 입력하면 다른 사람의 모바일 건강보험증이 문제 없이 설치됩니다', '입을 맞춘다면 다른 사람의 모바일 건강보험증으로 진료를 받을 수 있는 겁니다', '이뿐만이아닙니다', '한 명에 모바일 건강보험증을 둠각자의 휴대전화에 설치하는 것도 가능했습니다', '한 사람의 모발 건강보험증으로 여러 명이 진료 받는 것도 가능할 수 있다는 얘깁니다', '보험 중엔 사진이 없다 보니 병의원에서 본인 여부를 확인할 방법도 마땅치 않습니다', '의료 보험이 없다옆에 사람  신분증만 빌리면 된다 공기계 나 그걸 깔아 와서 그거만 내밀면 사실 저희는 죽을 수밖에 없는 시스템이거든요', '이런 문제에 대한 대책을 문의하자 건강보험공단은 통신사 인증을 본인 휴대폰으로만 인증 가능하도록 시스템 복원을 검토중이라고 해명했습니다', '대명시장 백화점 기자 나와 있습니다', '이게 다음 주부터 시행되지 문제점이 굉장히 많습니다', '이런 것들을 정도는 전혀 사전에못 하고 있던 건가요', '보건복지부는 오늘 오전에도이 제도가 월요일부터 시행된다는 내용을 담아서 보도자료를 배포했는데 당연히 이런 내용은 없었습니다', '저희 취재진에 문제를 제기한 이까 시간 뒤쯤에 건강보험공단에서 답을들을 수 있었는데요', '공단은 다른 사람의 휴대전화로모바일 건강보험증을 발급 받을 수 없게 인증시스템을 보완하는 걸 검토하겠다', '이렇게 밝혔습니다', '하지만 한 명에 모바일 건강보험여러대의 기기에서 쓸 수는 없다고 설명했는데요', '앞서 보셨던 것처럼 명의가 다른 휴대전화에 본인확인을 받는게 가능하다는걸 쉽확인할 수 있었습니다', '종합적으로 문제가 뭔지 파악을 해서 대책마련을 하는게 필요해 보입니다', '먹으면은 다른 사람이진료 받는게 가능한 거잖아요', '입원해서 어떻게 대책이 있는 겁니까 일단 건강보험공단은 두 사람이 작정을 하고 휴대전화 인증번호를 공유하는 것과원칙적으로 방지 하기는 좀 어렵다 기본적으로 건강보험증 관리는 소지자가 한다 이런 입장을 보이고 있습니다', '원칙적으로는 맞는 말해도 아니라는 대응이라는 지적을 피할 수는 없습니다', '저희가 확인해보니까 지난 년 동안의 다른 사람의 건강보험증을 이용한연평균 만 천 원 정도 적발이 된다고 합니다', '이런 허술한 본인 강화 제도로 이런 사례를 얼마나 줄일 수 있을지도 의문입니다', '알겠습니다', '세까지 박 과장이 되었습니다', '상 소식입니다', '서울에서 아파트 전세 구하기가 갈수록 어려워지면서 전셋값이계속 오르고 있습니다', '몇 몇 단지 예선 몇 달 사이에 수억원이 뛰기도 했습니다', '더위와 함께 앞으로 전당까지 이호건 기자가서울 성동구에 천세 대규모 아파트 단지입니다', '지난달 전용  제곱미터 전세억 천만 원의 책을 됐습니다', '두달전 거래 건보다 오른 겁니다', '이번 주 서울 아파트 전세가는  세대 단지 입주를 앞둔 강동구를 제외하고 모든 자치구에서 상승했습니다', '지난 년 연속 고른 건데 관련 통계 집회 후네 번째로 긴 상승입니다', '가장 큰 원인은 매물부족 이달 서울아파트만 원 이하로 개월 정도 와 비교하면  줄어듭니다', '올해 서울 입주 예정 물량은 으로 지난해보다줄어든데다 전세 빌라 대신 아파트 전세 찾는 손님도 영향을 미쳤습니다', '향후 상황도 나아지기 어렵습니다', '오는 월 말은 세입자가 최대  만 인상된 전세가로 년 더 살 수 있게 한 임대차 입법이 년차가 되는 그러니까 첫 만개를집주인들은 그동안 못 올린 걸 현재 시세에 맞게 한꺼번에 올리는 움직임을 보이고 있습니다', '그동안에는 이제 올리고 싶어도못했으니까요', '그래서 이번에 인제 그게 끝나니까 이렇게 제대로 올리려고 하는 겁니다', '실제로 서초구 아파트 전용 제곱미터최근 전세가 억원에 체결했는데이는 년 전보다 억 오른 가격입니다', '상한선이 없어지는이후에는 가을 이사철과 맞물려 전셋값이 더 오를 가능성이 높습니다', '정부도 심각성을 인지하고 다음 주 전세는수도권 공급부족 단기간에 해소할 뾰족한 수가 없어 고민이 커지고 있습니다', '이용합니다', '이상기후의 여파로 농산물 가격이 좀처럼 잡히지 않고 있습니다', '올해는 특히 마늘이 걱정입니다', '잦은 비 와부족한 일조량 때문에 상품성이 떨어지는 마늘이 많다고 합니다', '현장을 박애린 기자가 취재했습니다', '수확한 마늘을 말리는 작업이 한창인 제주의 마늘 밭입니다', '겉으론 멀쩡해보이지만 데를 벗기니 줄기가 여러 개 나옵니다', '마늘한쪽여러 쪽으로 갈라집니다', '여기서 쪽이 또네 개 낱개로 분리되지 아니면 이쪽이 너무 작아 상품 가치가 없는 것들입니다', '마늘 생육기  월 잦은 비바 일조량 부족으로 비교적 따뜻했던 기온이 가장 큰 원인입니다', '작년 대비 강우량도 많이 왔다고 하더라고요', '월 달에 원래 같이 뭐 전체적으로 그 벌 마늘이 생성된 거는마늘 농사 접을까 도저히 하고 있습니다', '이 밤만 하더라도 상품성 없는 벌마늘 비율이 절반을 넘는데 다른 밥도 상황은수학 해도 팔지 못하는 마늘만 잔뜩 나와 인력은 인력 대로 들고 손해가 막심합니다', '제주에서 시작된 벌마늘 피해가 전남 경남 등으로 빠르게 확산하면서 정부는 농업 죄로 인정하고 재난지원금 지급에 나섰습니다', '올해 국산마늘 생산량은 평년보다 줄어들 수밖에 없는 상황 현재는 지난해 저장해둔 마늘이 계속 풀리는 시기라 가격은 유지되고 있는데다음 달이면 저장 물량은 차차 소진됩니다', '수입물량 추위를 봐야겠지만 여름 정도부터 마늘 가격이 오를 수 있습니다놓고 보면은 단위당 수확량이 조금 더 떨어질 거예요', '가격은 뭐 전이라 평균보다는 상승할 가능성이 있습니다', '이상기후가 과일이에요', '채소 작 황해도 두루 영향을 미치면서 물관리가 층 까다로워지고 있습니다', '박예린입니다', '이종섭 전 국방부장관 일 해병대 박정훈 전수 사단장 한 명 재판에 증인으로 채택합니다', '대통령 시로부터 특정인을 혐의자에서 빼라는 말을 전달 받은 적이 없다며 법정에 나가서 증언 하겠다고 밝혔습니다', '켜졌습니다', '차혁명 공판의 군사법원에 출석한 박정순 대령 박대령 직원 재판이 없어특검법 수영을 촉구했습니다', '대통령은 특검법을 수용하고 국방 장관은 지금처럼 정하게 군사재판에 중립을 지키고오늘 공판에서 재판부는 이중섭 전 국방부장관을 증인으로 불러 달라는 박대령 측 요청을 받았습니다', '이 전 장관은보류 명령을 하게 된 이유와 관련 있어 명령이 정당한지 확인할 필요가 있다며 증인채택 이유를 설명했습니다', '이 전 장관의 휴대전화 통화내역과 문자 메시지에 대한 통신자료조회 신청도 허락했습니다', '이전 상권 직원 지정된']

# %%
# Step 3: 주제 추출 및 요약
topics = extract_topics_and_summarize(processed_text)
print("Extracted Topics and Summaries:\n", topics)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# WARNING:tensorflow:From C:\Users\jwoo3\anaconda3\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [Kss]: From C:\Users\jwoo3\anaconda3\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Topics extracted and summarized
# Extracted Topics and Summaries:
#  {'주제 1': '은지 병원이 확인하기 위해서 입니다 병원이 확인하기 위해서입니다 신분증 지참 필수 란 안내 포스터가 붙은 한내과의원 의원 협조를 미리 받아모바일 건강보험 증으로 진료 접수를 해 봤습니다 건강보험증  코', '주제 2': '많 많도 원칙적으로는 맞는 말해도 아니라는 대응이라는 지적을 피할 수는 없습니다 원칙적으로는 맞는 말해도 아니라는 대응이라는 지적을 피할 수는 없습니다 이런 허술한 본인 강화 제도로 이런 사례를 얼마나 줄일 수 있을지도 의문이 나 있을', '주제 3': '됐 됐 왔습니다 대명시장 백화점 기자 나와 있습니다 이런 것들을 정도는 전혀 사전에못 하고 있던 건가요 이렇게 밝혔습니다 종합적으로 문제가 뭔지 파악을 해서 대책마련을 하는 게 필요해 보입니다 먹으면은 다른 사람이진료', '주제 4': '올해는 특히 마늘이 걱정입니다 잦은 비 와부족한 일조량 때문에 상품성이 떨어지는 마늘이 많다고 합니다 수확한 마늘을 말리는 작업이 한창인 제주의 마늘 밭입니다 마늘 생육', '주제 5': '등이 등 병원이 적발하기 적발하기 적발하기 적발하기 적발하기 적발하기 적발하기 적발하기 적발하기 확인됐습니다 하지만 기자가 제시한 모바일 건강보험증은 본인이 아닌 동료의 것입니다 어떻게 이게 가능한걸까 모바일 건강보험증 앱은'}

# %%
# 이 함수 호출부를 유지하고 실행하여 오류를 확인합니다.
try:
    print("\n추출된 주제 목록:")
    for idx, (topic, summary) in enumerate(topics.items(), start=1):
        print(f"{idx}. {summary}")

    selected_topic_idx = int(input("\n원하는 주제의 번호를 선택하세요: ")) - 1
    selected_topic = list(topics.keys())[selected_topic_idx]
    selected_summary = topics[selected_topic]
    print(f"\n선택된 주제: {selected_topic}")

    # Step 4: 주제 관련 문장 찾기 및 영상 자르기
    relevant_sentences, duration = find_relevant_sentences(processed_text, selected_summary)
    if not relevant_sentences:
        raise ValueError(f"선택된 주제 '{selected_topic}'와 관련된 문장을 찾을 수 없습니다.")
    print(f"Relevant sentences for topic '{selected_topic}': {relevant_sentences}")
    print(f"Total duration: {duration} seconds")

    # 중요 프레임 추출 (1분 내의 영상만을 대상으로)
    start_time = 0  # 예시 시작 시간 (초 단위)
    end_time = start_time + duration  # 실제 문장의 길이를 시간으로 환산
    timestamps, face_centers = extract_important_frames(video_file, start_time, end_time)
    focus_frame_index = np.argmax(face_centers)
    focus_frame = face_centers[focus_frame_index]  # 가장 중요한 프레임 선택

    print(f"Focus frame: {focus_frame}")  # Debugging line

    # 관련 문장에 해당하는 영상을 자르기
    output_file = 'videos/shorts_output.mp4'
    cut_video_with_focus(video_file, start_time, end_time, output_file, face_centers)
    print(f"Video cut and saved to {output_file}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# 추출된 주제 목록:
# 1. 은지 병원이 확인하기 위해서 입니다 병원이 확인하기 위해서입니다 신분증 지참 필수 란 안내 포스터가 붙은 한내과의원 의원 협조를 미리 받아모바일 건강보험 증으로 진료 접수를 해 봤습니다 건강보험증  코
# 2. 많 많도 원칙적으로는 맞는 말해도 아니라는 대응이라는 지적을 피할 수는 없습니다 원칙적으로는 맞는 말해도 아니라는 대응이라는 지적을 피할 수는 없습니다 이런 허술한 본인 강화 제도로 이런 사례를 얼마나 줄일 수 있을지도 의문이 나 있을
# 3. 됐 됐 왔습니다 대명시장 백화점 기자 나와 있습니다 이런 것들을 정도는 전혀 사전에못 하고 있던 건가요 이렇게 밝혔습니다 종합적으로 문제가 뭔지 파악을 해서 대책마련을 하는 게 필요해 보입니다 먹으면은 다른 사람이진료
# 4. 올해는 특히 마늘이 걱정입니다 잦은 비 와부족한 일조량 때문에 상품성이 떨어지는 마늘이 많다고 합니다 수확한 마늘을 말리는 작업이 한창인 제주의 마늘 밭입니다 마늘 생육
# 5. 등이 등 병원이 적발하기 적발하기 적발하기 적발하기 적발하기 적발하기 적발하기 적발하기 적발하기 확인됐습니다 하지만 기자가 제시한 모바일 건강보험증은 본인이 아닌 동료의 것입니다 어떻게 이게 가능한걸까 모바일 건강보험증 앱은
#
# 선택된 주제: 주제 3
# Relevant sentences for topic '주제 3': ['환자가 건강보험 자격이 있는지 혹시 다른 사람 명의로 진료받는 건 아닌지 병원이 확인하기 위해서입니다', '그런데이 모바일다른 사람의 휴대전화 해도 쉽게 설치할 수 있고 또 그걸 병원이 적발하기 어렵다는 사실이 저희 취재 결과 확인됐습니다', '기자의 단독 보도입니다', '신분증 지참 필수 란 안내 포스터가 붙은 한내과의원 의원 협조를 미리 받아모바일 건강보험증으로 진료 접수를 해 봤습니다', '건강보험증  코드를 병원 기기로 인식하자 건강 보험 자격 확인이 되고 문제 없이완료됐습니다', '하지만 기자가 제시한 모바일 건강보험증은 본인이 아닌 동료의 것입니다', '타인 명의의 건강보험증을 병원에 제출했는데걸러내지 못한 겁니다', '어떻게 이게 가능한걸까 모바일 건강보험증 앱은 휴대 전화 번호를 입력한뒤 인증번호를 받아 본인임을 확인하는설치할 수 있습니다', '그런데 두 사람이 미리 짜고 상대방 휴대전화에 인증번호를 받을 사람의 전화 번호를 입력하고그렇게 받은 인증번호를 전달해 휴대 전화에 입력하면 다른 사람의 모바일 건강보험증이 문제 없이 설치됩니다', '입을 맞춘다면 다른 사람의 모바일 건강보험증으로 진료를 받을 수 있는 겁니다', '한 명에 모바일 건강보험증을 둠각자의 휴대전화에 설치하는 것도 가능했습니다']
# Total duration: 57.199999999999996 seconds
# 870it [04:01,  3.60it/s]
# Extracted face centers: [900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 1695, 1695, 1653, 1585, 1557, 949, 920, 1057, 900, 1057, 880, 840, 1000, 820, 801, 801, 781, 761, 741, 741, 721, 701, 698, 681, 674, 661, 650, 854, 846, 621, 601, 818, 804, 791, 785, 514, 514, 509, 500, 500, 497, 486, 486, 486, 474, 474, 463, 463, 459, 451, 445, 440, 433, 428, 428, 417, 417, 417, 405, 405, 394, 394, 394, 394, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 394, 394, 394, 394, 394, 394, 394, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 385, 1407, 1403, 1384, 1384, 1384, 1384, 1384, 1384, 1384, 1393, 1393, 1393, 1393, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1403, 1403, 1403, 1403, 1403, 1403, 1407, 1407, 1407, 1407, 1407, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1413, 1413, 1413, 1413, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1413, 1419, 1413, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1413, 1413, 1419, 1413, 1419, 1419, 1419, 1419, 1413, 1413, 1419, 1419, 1413, 1413, 1413, 1413, 1413, 1413, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1422, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1419, 1419, 1419, 1419, 1419, 1419, 1419, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1384, 1384, 1384, 1384, 1384, 1384, 1384, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1396, 1393, 1396, 1393, 1393, 1393, 1393, 1384, 1384, 1384, 1384, 1384, 1384, 1384, 1384, 1384, 1384, 1384, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1393, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1403, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1396, 1403, 1396, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1407, 1673, 1673, 1673, 1673, 1673, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1419, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, 1413, ...
# Focus frame: 1695
# Time: 0, Index: 0, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 1, Index: 1, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 2, Index: 2, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 3, Index: 3, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 4, Index: 4, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 5, Index: 5, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 6, Index: 6, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 7, Index: 7, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 8, Index: 8, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 9, Index: 9, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 10, Index: 10, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 11, Index: 11, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 12, Index: 12, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 13, Index: 13, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 14, Index: 14, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 15, Index: 15, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 16, Index: 16, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 17, Index: 17, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 18, Index: 18, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 19, Index: 19, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 20, Index: 20, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 21, Index: 21, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 22, Index: 22, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 23, Index: 23, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 24, Index: 24, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 25, Index: 25, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 26, Index: 26, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 27, Index: 27, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 28, Index: 28, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 29, Index: 29, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 30, Index: 30, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 31, Index: 31, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 32, Index: 32, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 33, Index: 33, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 34, Index: 34, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 35, Index: 35, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 36, Index: 36, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 37, Index: 37, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 38, Index: 38, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 39, Index: 39, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 40, Index: 40, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 41, Index: 41, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 42, Index: 42, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 43, Index: 43, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 44, Index: 44, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 45, Index: 45, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 46, Index: 46, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 47, Index: 47, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 48, Index: 48, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 49, Index: 49, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 50, Index: 50, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 51, Index: 51, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 52, Index: 52, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 53, Index: 53, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 54, Index: 54, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 55, Index: 55, Center X: 1695
# Received center_x: 1695
# Cropping image: height=720, width=1285, center_x=1695, new_width=405, left=880
# Time: 56, Index: 56, Center X: 1695
# Received center_x: 1695
# Cropping image: height=720, width=1285, center_x=1695, new_width=405, left=880
# Time: 57, Index: 57, Center X: 1653
# Received center_x: 1653
# Cropping image: height=720, width=1285, center_x=1653, new_width=405, left=880
# Time: 58, Index: 58, Center X: 1585
# Received center_x: 1585
# Cropping image: height=720, width=1285, center_x=1585, new_width=405, left=880
# Time: 59, Index: 59, Center X: 1557
# Received center_x: 1557
# Cropping image: height=720, width=1285, center_x=1557, new_width=405, left=880
# Time: 60, Index: 60, Center X: 949
# Received center_x: 949
# Cropping image: height=720, width=1285, center_x=949, new_width=405, left=747
# Time: 61, Index: 61, Center X: 920
# Received center_x: 920
# Cropping image: height=720, width=1285, center_x=920, new_width=405, left=718
# Time: 62, Index: 62, Center X: 1057
# Received center_x: 1057
# Cropping image: height=720, width=1285, center_x=1057, new_width=405, left=855
# Time: 63, Index: 63, Center X: 900
# Received center_x: 900
# Cropping image: height=720, width=1285, center_x=900, new_width=405, left=698
# Time: 64, Index: 64, Center X: 1057
# Received center_x: 1057
# Cropping image: height=720, width=1285, center_x=1057, new_width=405, left=855
# Time: 65, Index: 65, Center X: 880
# Received center_x: 880
# Cropping image: height=720, width=1285, center_x=880, new_width=405, left=678
# Time: 66, Index: 66, Center X: 840
# Received center_x: 840
# Cropping image: height=720, width=1285, center_x=840, new_width=405, left=638
# Time: 67, Index: 67, Center X: 1000
# Received center_x: 1000
# Cropping image: height=720, width=1285, center_x=1000, new_width=405, left=798
# Time: 68, Index: 68, Center X: 820
# Received center_x: 820
# Cropping image: height=720, width=1285, center_x=820, new_width=405, left=618
# Time: 69, Index: 69, Center X: 801
# Received center_x: 801
# Cropping image: height=720, width=1285, center_x=801, new_width=405, left=599
# Time: 70, Index: 70, Center X: 801
# Received center_x: 801
# Cropping image: height=720, width=1285, center_x=801, new_width=405, left=599
# Time: 71, Index: 71, Center X: 781
# Received center_x: 781
# Cropping image: height=720, width=1285, center_x=781, new_width=405, left=579
# Time: 72, Index: 72, Center X: 761
# Received center_x: 761
# Cropping image: height=720, width=1285, center_x=761, new_width=405, left=559
# Time: 73, Index: 73, Center X: 741
# Received center_x: 741
# Cropping image: height=720, width=1285, center_x=741, new_width=405, left=539
# Time: 74, Index: 74, Center X: 741
# Received center_x: 741
# Cropping image: height=720, width=1285, center_x=741, new_width=405, left=539
# Time: 75, Index: 75, Center X: 721
# Received center_x: 721
# Cropping image: height=720, width=1285, center_x=721, new_width=405, left=519
# Time: 76, Index: 76, Center X: 701
# Received center_x: 701
# Cropping image: height=720, width=1285, center_x=701, new_width=405, left=499
# Time: 77, Index: 77, Center X: 698
# Received center_x: 698
# Cropping image: height=720, width=1285, center_x=698, new_width=405, left=496
# Time: 78, Index: 78, Center X: 681
# Received center_x: 681
# Cropping image: height=720, width=1285, center_x=681, new_width=405, left=479
# Time: 79, Index: 79, Center X: 674
# Received center_x: 674
# Cropping image: height=720, width=1285, center_x=674, new_width=405, left=472
# Time: 80, Index: 80, Center X: 661
# Received center_x: 661
# Cropping image: height=720, width=1285, center_x=661, new_width=405, left=459
# Time: 81, Index: 81, Center X: 650
# Received center_x: 650
# Cropping image: height=720, width=1285, center_x=650, new_width=405, left=448
# Time: 82, Index: 82, Center X: 854
# Received center_x: 854
# Cropping image: height=720, width=1285, center_x=854, new_width=405, left=652
# Time: 83, Index: 83, Center X: 846
# Received center_x: 846
# Cropping image: height=720, width=1285, center_x=846, new_width=405, left=644
# Time: 84, Index: 84, Center X: 621
# Received center_x: 621
# Cropping image: height=720, width=1285, center_x=621, new_width=405, left=419
# Time: 85, Index: 85, Center X: 601
# Received center_x: 601
# Cropping image: height=720, width=1285, center_x=601, new_width=405, left=399
# Time: 86, Index: 86, Center X: 818
# Received center_x: 818
# Cropping image: height=720, width=1285, center_x=818, new_width=405, left=616
# Time: 87, Index: 87, Center X: 804
# Received center_x: 804
# Cropping image: height=720, width=1285, center_x=804, new_width=405, left=602
# Time: 88, Index: 88, Center X: 791
# Received center_x: 791
# Cropping image: height=720, width=1285, center_x=791, new_width=405, left=589
# Time: 89, Index: 89, Center X: 785
# Received center_x: 785
# Cropping image: height=720, width=1285, center_x=785, new_width=405, left=583
# Time: 90, Index: 90, Center X: 514
# Received center_x: 514
# Cropping image: height=720, width=1285, center_x=514, new_width=405, left=312
# Time: 91, Index: 91, Center X: 514
# Received center_x: 514
# Cropping image: height=720, width=1285, center_x=514, new_width=405, left=312
# Time: 92, Index: 92, Center X: 509
# Received center_x: 509
# Cropping image: height=720, width=1285, center_x=509, new_width=405, left=307
# Time: 93, Index: 93, Center X: 500
# Received center_x: 500
# Cropping image: height=720, width=1285, center_x=500, new_width=405, left=298
# Time: 94, Index: 94, Center X: 500
# Received center_x: 500
# Cropping image: height=720, width=1285, center_x=500, new_width=405, left=298
# Time: 95, Index: 95, Center X: 497
# Received center_x: 497
# Cropping image: height=720, width=1285, center_x=497, new_width=405, left=295
# Time: 96, Index: 96, Center X: 486
# Received center_x: 486
# Cropping image: height=720, width=1285, center_x=486, new_width=405, left=284
# Time: 97, Index: 97, Center X: 486
# Received center_x: 486
# Cropping image: height=720, width=1285, center_x=486, new_width=405, left=284
# Time: 98, Index: 98, Center X: 486
# Received center_x: 486
# Cropping image: height=720, width=1285, center_x=486, new_width=405, left=284
# Time: 99, Index: 99, Center X: 474
# Received center_x: 474
# Cropping image: height=720, width=1285, center_x=474, new_width=405, left=272
# Time: 100, Index: 100, Center X: 474
# Received center_x: 474
# Cropping image: height=720, width=1285, center_x=474, new_width=405, left=272
# Time: 101, Index: 101, Center X: 463
# Received center_x: 463
# Cropping image: height=720, width=1285, center_x=463, new_width=405, left=261
# Time: 102, Index: 102, Center X: 463
# Received center_x: 463
# Cropping image: height=720, width=1285, center_x=463, new_width=405, left=261
# Time: 103, Index: 103, Center X: 459
# Received center_x: 459
# Cropping image: height=720, width=1285, center_x=459, new_width=405, left=257
# Time: 104, Index: 104, Center X: 451
# Received center_x: 451
# Cropping image: height=720, width=1285, center_x=451, new_width=405, left=249
# Time: 105, Index: 105, Center X: 445
# Received center_x: 445
# Cropping image: height=720, width=1285, center_x=445, new_width=405, left=243
# Time: 106, Index: 106, Center X: 440
# Received center_x: 440
# Cropping image: height=720, width=1285, center_x=440, new_width=405, left=238
# Time: 107, Index: 107, Center X: 433
# Received center_x: 433
# Cropping image: height=720, width=1285, center_x=433, new_width=405, left=231
# Time: 108, Index: 108, Center X: 428
# Received center_x: 428
# Cropping image: height=720, width=1285, center_x=428, new_width=405, left=226
# Time: 109, Index: 108, Center X: 428
# Received center_x: 428
# Cropping image: height=720, width=1285, center_x=428, new_width=405, left=226
# Time: 110, Index: 110, Center X: 417
# Received center_x: 417
# Cropping image: height=720, width=1285, center_x=417, new_width=405, left=215
# Time: 111, Index: 111, Center X: 417
# Received center_x: 417
# Cropping image: height=720, width=1285, center_x=417, new_width=405, left=215
# Time: 112, Index: 112, Center X: 417
# Received center_x: 417
# Cropping image: height=720, width=1285, center_x=417, new_width=405, left=215
# Time: 113, Index: 112, Center X: 417
# Received center_x: 417
# Cropping image: height=720, width=1285, center_x=417, new_width=405, left=215
# Time: 114, Index: 114, Center X: 405
# Received center_x: 405
# Cropping image: height=720, width=1285, center_x=405, new_width=405, left=203
# Time: 115, Index: 115, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 116, Index: 116, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 117, Index: 116, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 118, Index: 118, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 119, Index: 119, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 120, Index: 120, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 121, Index: 120, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 122, Index: 122, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 123, Index: 123, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 124, Index: 124, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 125, Index: 124, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 126, Index: 126, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 127, Index: 127, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 128, Index: 128, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 129, Index: 129, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 130, Index: 130, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 131, Index: 131, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 132, Index: 132, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 133, Index: 133, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 134, Index: 134, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 135, Index: 135, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 136, Index: 136, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 137, Index: 137, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 138, Index: 138, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 139, Index: 139, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 140, Index: 140, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 141, Index: 141, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 142, Index: 142, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 143, Index: 143, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 144, Index: 144, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 145, Index: 145, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 146, Index: 146, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 147, Index: 147, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 148, Index: 148, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 149, Index: 149, Center X: 394
# Received center_x: 394
# Cropping image: height=720, width=1285, center_x=394, new_width=405, left=192
# Time: 150, Index: 150, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 151, Index: 151, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 152, Index: 152, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 153, Index: 153, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 154, Index: 154, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 155, Index: 155, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 156, Index: 156, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 157, Index: 157, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 158, Index: 158, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 159, Index: 159, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 160, Index: 160, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 161, Index: 161, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 162, Index: 162, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 163, Index: 163, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 164, Index: 164, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 165, Index: 165, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 166, Index: 166, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 167, Index: 167, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 168, Index: 168, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 169, Index: 169, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 170, Index: 170, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 171, Index: 171, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 172, Index: 172, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 173, Index: 173, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 174, Index: 174, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 175, Index: 175, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 176, Index: 176, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 177, Index: 177, Center X: 385
# Received center_x: 385
# Cropping image: height=720, width=1285, center_x=385, new_width=405, left=183
# Time: 178, Index: 178, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 179, Index: 179, Center X: 1403
# Received center_x: 1403
# Cropping image: height=720, width=1285, center_x=1403, new_width=405, left=880
# Time: 180, Index: 180, Center X: 1384
# Received center_x: 1384
# Cropping image: height=720, width=1285, center_x=1384, new_width=405, left=880
# Time: 181, Index: 181, Center X: 1384
# Received center_x: 1384
# Cropping image: height=720, width=1285, center_x=1384, new_width=405, left=880
# Time: 182, Index: 182, Center X: 1384
# Received center_x: 1384
# Cropping image: height=720, width=1285, center_x=1384, new_width=405, left=880
# Time: 183, Index: 183, Center X: 1384
# Received center_x: 1384
# Cropping image: height=720, width=1285, center_x=1384, new_width=405, left=880
# Time: 184, Index: 184, Center X: 1384
# Received center_x: 1384
# Cropping image: height=720, width=1285, center_x=1384, new_width=405, left=880
# Time: 185, Index: 185, Center X: 1384
# Received center_x: 1384
# Cropping image: height=720, width=1285, center_x=1384, new_width=405, left=880
# Time: 186, Index: 186, Center X: 1384
# Received center_x: 1384
# Cropping image: height=720, width=1285, center_x=1384, new_width=405, left=880
# Time: 187, Index: 187, Center X: 1393
# Received center_x: 1393
# Cropping image: height=720, width=1285, center_x=1393, new_width=405, left=880
# Time: 188, Index: 188, Center X: 1393
# Received center_x: 1393
# Cropping image: height=720, width=1285, center_x=1393, new_width=405, left=880
# Time: 189, Index: 189, Center X: 1393
# Received center_x: 1393
# Cropping image: height=720, width=1285, center_x=1393, new_width=405, left=880
# Time: 190, Index: 190, Center X: 1393
# Received center_x: 1393
# Cropping image: height=720, width=1285, center_x=1393, new_width=405, left=880
# Time: 191, Index: 191, Center X: 1396
# Received center_x: 1396
# Cropping image: height=720, width=1285, center_x=1396, new_width=405, left=880
# Time: 192, Index: 192, Center X: 1396
# Received center_x: 1396
# Cropping image: height=720, width=1285, center_x=1396, new_width=405, left=880
# Time: 193, Index: 193, Center X: 1396
# Received center_x: 1396
# Cropping image: height=720, width=1285, center_x=1396, new_width=405, left=880
# Time: 194, Index: 194, Center X: 1396
# Received center_x: 1396
# Cropping image: height=720, width=1285, center_x=1396, new_width=405, left=880
# Time: 195, Index: 195, Center X: 1396
# Received center_x: 1396
# Cropping image: height=720, width=1285, center_x=1396, new_width=405, left=880
# Time: 196, Index: 196, Center X: 1396
# Received center_x: 1396
# Cropping image: height=720, width=1285, center_x=1396, new_width=405, left=880
# Time: 197, Index: 197, Center X: 1396
# Received center_x: 1396
# Cropping image: height=720, width=1285, center_x=1396, new_width=405, left=880
# Time: 198, Index: 198, Center X: 1396
# Received center_x: 1396
# Cropping image: height=720, width=1285, center_x=1396, new_width=405, left=880
# Time: 199, Index: 199, Center X: 1403
# Received center_x: 1403
# Cropping image: height=720, width=1285, center_x=1403, new_width=405, left=880
# Time: 200, Index: 200, Center X: 1403
# Received center_x: 1403
# Cropping image: height=720, width=1285, center_x=1403, new_width=405, left=880
# Time: 201, Index: 201, Center X: 1403
# Received center_x: 1403
# Cropping image: height=720, width=1285, center_x=1403, new_width=405, left=880
# Time: 202, Index: 202, Center X: 1403
# Received center_x: 1403
# Cropping image: height=720, width=1285, center_x=1403, new_width=405, left=880
# Time: 203, Index: 203, Center X: 1403
# Received center_x: 1403
# Cropping image: height=720, width=1285, center_x=1403, new_width=405, left=880
# Time: 204, Index: 204, Center X: 1403
# Received center_x: 1403
# Cropping image: height=720, width=1285, center_x=1403, new_width=405, left=880
# Time: 205, Index: 205, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 206, Index: 206, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 207, Index: 207, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 208, Index: 208, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 209, Index: 209, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 210, Index: 210, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 211, Index: 211, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 212, Index: 212, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 213, Index: 213, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 214, Index: 214, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 215, Index: 215, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 216, Index: 216, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 217, Index: 217, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 218, Index: 217, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 219, Index: 219, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 220, Index: 220, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 221, Index: 221, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 222, Index: 222, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 223, Index: 222, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 224, Index: 224, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 225, Index: 225, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 226, Index: 225, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 227, Index: 227, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 228, Index: 228, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 229, Index: 229, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 230, Index: 230, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 231, Index: 230, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 232, Index: 232, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 233, Index: 233, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 234, Index: 233, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 235, Index: 235, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 236, Index: 236, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 237, Index: 237, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 238, Index: 238, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 239, Index: 238, Center X: 1407
# Received center_x: 1407
# Cropping image: height=720, width=1285, center_x=1407, new_width=405, left=880
# Time: 240, Index: 240, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 241, Index: 241, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 242, Index: 241, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 243, Index: 243, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 244, Index: 244, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 245, Index: 245, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 246, Index: 246, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 247, Index: 246, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 248, Index: 248, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 249, Index: 249, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 250, Index: 249, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 251, Index: 251, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 252, Index: 252, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 253, Index: 253, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 254, Index: 254, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 255, Index: 254, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 256, Index: 256, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 257, Index: 257, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 258, Index: 258, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 259, Index: 259, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 260, Index: 260, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 261, Index: 261, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 262, Index: 262, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 263, Index: 263, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 264, Index: 264, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 265, Index: 265, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 266, Index: 266, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 267, Index: 267, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 268, Index: 268, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 269, Index: 269, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 270, Index: 270, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 271, Index: 271, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 272, Index: 272, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 273, Index: 273, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 274, Index: 274, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 275, Index: 275, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 276, Index: 276, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 277, Index: 277, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 278, Index: 278, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 279, Index: 279, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 280, Index: 280, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 281, Index: 281, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 282, Index: 282, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 283, Index: 283, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 284, Index: 284, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 285, Index: 285, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 286, Index: 286, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 287, Index: 287, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 288, Index: 288, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 289, Index: 289, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 290, Index: 290, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 291, Index: 291, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 292, Index: 292, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 293, Index: 293, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 294, Index: 294, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 295, Index: 295, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 296, Index: 296, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 297, Index: 297, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 298, Index: 298, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 299, Index: 299, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 300, Index: 300, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 301, Index: 301, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 302, Index: 302, Center X: 1413
# Received center_x: 1413
# Cropping image: height=720, width=1285, center_x=1413, new_width=405, left=880
# Time: 303, Index: 303, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 304, Index: 304, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 305, Index: 305, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 306, Index: 306, Center X: 1419
# Received center_x: 1419
# Cropping image: height=720, width=1285, center_x=1419, new_width=405, left=880
# Time: 307, Index: 307, Center X: 1419
# ...
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1606, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1607, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1608, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1609, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1610, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1611, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1612, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1613, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1614, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1615, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1616, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1617, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1618, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1619, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1620, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1621, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1622, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1623, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1624, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1625, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1626, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1627, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1628, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1629, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1630, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1631, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1632, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1633, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1634, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1635, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1636, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1637, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1638, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1639, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1640, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1641, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1642, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1643, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1644, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1645, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1646, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1647, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1648, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1649, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1650, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1651, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1652, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1653, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1654, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1655, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1656, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1657, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1658, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1659, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1660, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1661, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1662, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1663, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1664, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1665, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1666, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1667, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1668, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1669, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1670, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1671, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1672, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1673, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1674, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1675, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1676, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1677, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1678, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1679, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1680, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1681, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1682, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1683, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1684, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1685, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1686, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1687, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1688, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1689, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1690, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1691, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1692, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1693, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1694, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1695, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1696, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1697, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1698, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1699, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1700, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1701, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1702, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1703, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1704, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1705, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1706, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1707, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1708, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1709, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1710, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1711, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1712, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1713, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1714, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Time: 1715, Index: 869, Center X: 1665
# Received center_x: 1665
# Cropping image: height=720, width=1285, center_x=1665, new_width=405, left=880
# Moviepy - Building video videos/shorts_output.mp4.
# MoviePy - Writing audio in shorts_outputTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video videos/shorts_output.mp4
# Moviepy - Done !
# Moviepy - video ready videos/shorts_output.mp4
# Video cut and saved to videos/shorts_output.mp4
